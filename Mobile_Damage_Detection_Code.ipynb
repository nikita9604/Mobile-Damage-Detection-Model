# %% [markdown]
# ## OPTION1 - Using yolov8n model
#
# Train YOLOv8 model using the standard hyperparameters, then evaluate the model on the validation dataset, and finally summarize the training results, including performance metrics and confirmation of saved checkpoints.
# The training data YAML file is located at [/content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/data.yaml](https://)

# %% [markdown]
# ### Setup & Installation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_yaml_path = '/content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/data.yaml' # @param {type: "string"}
print(f"Data YAML path set to: {data_yaml_path}")
# Out:
# Data YAML path set to: /content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/data.yaml

# %%
# !pip install ultralytics
import ultralytics
print("Ultralytics library installed and imported successfully.")
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.232-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.9.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.24.0+cu126)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.31.0)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2025.11.12)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.3.232-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 28.6 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.232 ultralytics-thop-2.0.18
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics library installed and imported successfully.

# %% [markdown]
# ### Load Dataset

# %%
model = ultralytics.YOLO('yolov8n.pt') # Load a pre-trained YOLOv8n model
print("YOLOv8 model initialized:")
print(model.info())
# Out:
# YOLOv8 model initialized:
# YOLOv8n summary: 129 layers, 3,157,200 parameters, 0 gradients, 8.9 GFLOPs
# (129, 3157200, 0, 8.8575488)

# %% [markdown]
# ### Model Training

# %%
# first 50 epochs (Iteration 1)
results = model.train(
    model='yolov8n.pt',
    data=data_yaml_path,
    epochs=50,
    imgsz=640,
    batch=16,
    lr0=0.01,
    lrf=0.01,
    optimizer='SGD',
    weight_decay=0.0005,
    momentum=0.937,
    hsv_h=0.015,
    hsv_s=0.7,
    hsv_v=0.4,
    degrees=0.0,
    translate=0.1,
    scale=0.5,
    flipud=0.0,
    fliplr=0.5,
    mosaic=1.0,
    mixup=0.0,
    save_period=15
)
print("Training completed. Results are stored in the 'runs' directory.")
# Out:
# Ultralytics 8.3.231 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train2, nbs=64, nms=False, opset=None, optimize=False, optimizer=SGD, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/train2, save_frames=False, save_json=False, save_period=15, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 21.0MB/s 0.0s
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751897  ultralytics.nn.modules.head.Detect           [3, [64, 128, 256]]
# Model summary: 129 layers, 3,011,433 parameters, 3,011,417 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 68.4MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 2.4±3.9 ms, read: 0.1±0.1 MB/s, size: 69.9 KB)
# train: Scanning /content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/train/labels.cache... 1199 images, 271 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1199/1199 1.8Mit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.6±0.2 ms, read: 0.2±0.1 MB/s, size: 113.2 KB)
# val: Scanning /content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/valid/labels.cache... 702 images, 172 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 702/702 872.7Kit/s 0.0s
# Plotting labels to /content/runs/detect/train2/labels.jpg...
# optimizer: SGD(lr=0.01, momentum=0.937) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/train2
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50         2G      1.802      3.778      1.757         57        640: 100% ━━━━━━━━━━━━ 75/75 2.0it/s 36.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 25.0s/it 9:10
#                    all        702       1266     0.0729      0.392      0.123     0.0494
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      2.48G      1.805      3.031       1.68         35        640: 100% ━━━━━━━━━━━━ 75/75 3.1it/s 24.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 3.3it/s 6.7s
#                    all        702       1266      0.663      0.295       0.27       0.11
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      2.48G      1.878      2.883      1.725         56        640: 100% ━━━━━━━━━━━━ 75/75 3.1it/s 23.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.8it/s 7.9s
#                    all        702       1266      0.618      0.289      0.234     0.0891
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      2.48G       1.91      2.786      1.767         41        640: 100% ━━━━━━━━━━━━ 75/75 3.2it/s 23.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.7it/s 8.0s
#                    all        702       1266      0.293      0.281      0.192     0.0687
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      2.48G       1.89        2.6      1.766         59        640: 100% ━━━━━━━━━━━━ 75/75 3.0it/s 24.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 3.3it/s 6.6s
#                    all        702       1266      0.471      0.233       0.26      0.104
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      2.48G      1.888      2.542      1.749         52        640: 100% ━━━━━━━━━━━━ 75/75 3.1it/s 24.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 3.1it/s 7.1s
#                    all        702       1266      0.439      0.292       0.29       0.12
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      2.48G      1.869      2.548      1.803         32        640: 100% ━━━━━━━━━━━━ 75/75 3.2it/s 23.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.7it/s 8.2s
#                    all        702       1266      0.401      0.345      0.327       0.14
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      2.48G      1.845      2.432      1.761         39        640: 100% ━━━━━━━━━━━━ 75/75 3.2it/s 23.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.8it/s 7.9s
#                    all        702       1266      0.509      0.346      0.317      0.126
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      2.49G      1.815      2.349      1.742         41        640: 100% ━━━━━━━━━━━━ 75/75 3.0it/s 25.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 3.3it/s 6.6s
#                    all        702       1266      0.483      0.305      0.317      0.128
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50       2.5G      1.797      2.327      1.742         34        640: 100% ━━━━━━━━━━━━ 75/75 3.1it/s 24.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 3.3it/s 6.7s
#                    all        702       1266      0.393      0.349      0.274      0.109
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50       2.5G      1.782      2.291      1.733         74        640: 100% ━━━━━━━━━━━━ 75/75 3.2it/s 23.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.8it/s 8.0s
#                    all        702       1266      0.552      0.355      0.375      0.161
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50       2.5G      1.787      2.253      1.727         51        640: 100% ━━━━━━━━━━━━ 75/75 3.2it/s 23.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.9it/s 7.5s
#                    all        702       1266      0.477       0.38      0.359      0.149
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50       2.5G      1.755      2.214      1.692         28        640: 100% ━━━━━━━━━━━━ 75/75 3.1it/s 24.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 3.3it/s 6.6s
#                    all        702       1266      0.562      0.398      0.428      0.196
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      2.51G      1.712      2.193      1.671         49        640: 100% ━━━━━━━━━━━━ 75/75 3.1it/s 24.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 3.4it/s 6.5s
#                    all        702       1266      0.415      0.308      0.275      0.113
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      2
0.305
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      2.59G      1.305      1.301      1.398         28        640: 100% ━━━━━━━━━━━━ 75/75 3.2it/s 23.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 3.0it/s 7.4s
#                    all        702       1266      0.705      0.561      0.611      0.298
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      2.59G      1.291      1.312      1.404         18        640: 100% ━━━━━━━━━━━━ 75/75 3.1it/s 23.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.4it/s 9.1s
#                    all        702       1266      0.729      0.567      0.629      0.313
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      2.59G      1.287      1.262      1.393         28        640: 100% ━━━━━━━━━━━━ 75/75 3.3it/s 23.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.9it/s 7.5s
#                    all        702       1266      0.713      0.567      0.632      0.313
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      2.59G      1.278      1.265      1.376         32        640: 100% ━━━━━━━━━━━━ 75/75 3.1it/s 24.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 3.2it/s 6.9s
#                    all        702       1266      0.718      0.562      0.629      0.314
#
# 50 epochs completed in 0.601 hours.
# Optimizer stripped from /content/runs/detect/train2/weights/last.pt, 6.2MB
# Optimizer stripped from /content/runs/detect/train2/weights/best.pt, 6.2MB
#
# Validating /content/runs/detect/train2/weights/best.pt...
# Ultralytics 8.3.231 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.3it/s 9.6s
#                    all        702       1266      0.717      0.563      0.629      0.314
#             dead pixel        156        217      0.635      0.432      0.511      0.206
#                scratch        171        399      0.831      0.792      0.828      0.412
#           screen crack        336        650      0.686      0.466      0.548      0.324
# Speed: 0.3ms preprocess, 2.7ms inference, 0.0ms loss, 3.8ms postprocess per image
# Results saved to /content/runs/detect/train2
# Training completed. Results are stored in the 'runs' directory.

# %%
# Now running from epoch 51 to 150 (Iteration 2)
# Re-initialize the model with the best weights from the previous run
model_reloaded = ultralytics.YOLO('/content/runs/detect/train2/weights/best.pt')
results = model_reloaded.train(
    data=data_yaml_path,
    epochs=100,
    imgsz=640,
    batch=16,
    lr0=0.01,
    lrf=0.01,
    optimizer='SGD',
    weight_decay=0.0005,
    momentum=0.937,
    hsv_h=0.015,
    hsv_s=0.7,
    hsv_v=0.4,
    degrees=0.0,
    translate=0.1,
    scale=0.5,
    flipud=0.0,
    fliplr=0.5,
    mosaic=1.0,
    mixup=0.0,
    save_period=15
)
print("Training completed. Results are stored in the 'runs' directory.")
# Out:
# Ultralytics 8.3.231 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/content/runs/detect/train2/weights/best.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train4, nbs=64, nms=False, opset=None, optimize=False, optimizer=SGD, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/train4, save_frames=False, save_json=False, save_period=15, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751897  ultralytics.nn.modules.head.Detect           [3, [64, 128, 256]]
# Model summary: 129 layers, 3,011,433 parameters, 3,011,417 gradients, 8.2 GFLOPs
#
# Transferred 355/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.4±0.0 ms, read: 30.5±19.8 MB/s, size: 71.6 KB)
# train: Scanning /content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/train/labels.cache... 1199 images, 271 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1199/1199 575.0Kit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 1.8±1.7 ms, read: 6.1±2.2 MB/s, size: 106.3 KB)
# val: Scanning /content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/valid/labels.cache... 702 images, 172 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 702/702 725.0Kit/s 0.0s
# Plotting labels to /content/runs/detect/train4/labels.jpg...
# optimizer: SGD(lr=0.01, momentum=0.937) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/train4
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      2.19G      1.352      1.462        1.4         57        640: 100% ━━━━━━━━━━━━ 75/75 2.5it/s 30.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.8it/s 7.9s
#                    all        702       1266      0.669      0.575      0.606        0.3
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100       2.2G      1.349      1.422      1.392         35        640: 100% ━━━━━━━━━━━━ 75/75 3.2it/s 23.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.7it/s 8.3s
#                    all        702       1266      0.639      0.552      0.568      0.271
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100       2.2G      1.427      1.541      1.439         56        640: 100% ━━━━━━━━━━━━ 75/75 3.0it/s 24.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 3.0it/s 7.3s
#                    all        702       1266      0.627      0.494      0.526      0.251
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100       2.2G      1.516      1.729      1.493         41        640: 100% ━━━━━━━━━━━━ 75/75 3.1it/s 24.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 3.1it/s 7.1s
#                    all        702       1266      0.512      0.468      0.447      0.197
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100       2.2G      1.527      1.694      1.499         59        640: 100% ━━━━━━━━━━━━ 75/75 3.1it/s 24.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.7it/s 8.1s
#                    all        702       1266      0.543       0.48      0.483      0.218
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100       2.2G      1.575      1.804      1.521         52        640: 100% ━━━━━━━━━━━━ 75/75 3.2it/s 23.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 3.0it/s 7.3s
#                    all        702       1266      0.591      0.434      0.482       0.22
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100       2.2G      1.574      1.789      1.538         32        640: 100% ━━━━━━━━━━━━ 75/75 3.0it/s 24.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 3.2it/s 6.9s
#                    all        702       1266      0.575      0.495      0.497      0.226
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100       2.2G      1.566      1.774      1.532         39        640: 100% ━━━━━━━━━━━━ 75/75 3.2it/s 23.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 3.0it/s 7.4s
#                    all        702       1266      0.567      0.465      0.486      0.221
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100       2.2G      1.562      1.772      1.529         41        640: 100% ━━━━━━━━━━━━ 75/75 3.3it/s 23.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.6it/s 8.3s
#                    all        702       1266      0.485      0.451      0.422      0.188
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100       2.2G      1.542      1.753      1.523         34        640: 100% ━━━━━━━━━━━━ 75/75 3.2it/s 23.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 3.1it/s 7.2s
#                    all        702       1266      0.518      0.468      0.481      0.215
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100       2.2G      1.552      1.733      1.526         74        640: 100% ━━━━━━━━━━━━ 75/75 3.1it/s 24.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 3.0it/s 7.3s
#                    all        702       1266      0.536      0.399      0.396      0.175
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100       2.2G      1.562      1.742      1.543         51        640: 100% ━━━━━━━━━━━━ 75/75 3.1it/s 24.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 3.1it/s 7.2s
#                    all        702       1266      0.529       0.49      0.496      0.228
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100       2.2G      1.538       1.71      1.508         28        640: 100% ━━━━━━━━━━━━ 75/75 3.2it/s 23.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.7it/s 8.2s
#                    all        702       1266      0.656      0.468      0.527      0.242
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      2.21G      1.495      1.695      1.494         49        640: 100% ━━━━━━━━━━━━ 75/75 3.2it/s 23.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.7it/s 8.1s
#                    all        702       1266      0.608      0.452      0.488      0.232
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      2.22G      1.514      1.706      1.501         45        640: 100% ━━━━━━━━━━━━ 75/75 3.1it/s 24.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 3.1it/s 7
640: 100% ━━━━━━━━━━━━ 75/75 2.9it/s 25.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.7it/s 8.2s
#                    all        702       1266       0.83      0.618      0.707      0.357
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      2.29G      1.029     0.8241       1.18         26        640: 100% ━━━━━━━━━━━━ 75/75 2.8it/s 26.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 3.3it/s 6.7s
#                    all        702       1266       0.82      0.628        0.7      0.349
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      2.29G      1.017     0.7941       1.17         35        640: 100% ━━━━━━━━━━━━ 75/75 3.1it/s 24.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 3.3it/s 6.6s
#                    all        702       1266      0.785      0.644      0.696      0.351
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      2.29G     0.9959     0.7777      1.154         26        640: 100% ━━━━━━━━━━━━ 75/75 3.0it/s 24.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 3.2it/s 6.8s
#                    all        702       1266      0.828      0.615      0.693      0.353
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      2.29G     0.9826     0.7708      1.147         40        640: 100% ━━━━━━━━━━━━ 75/75 3.3it/s 22.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.8it/s 7.9s
#                    all        702       1266      0.794      0.646      0.707      0.359
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      2.29G     0.9626      0.725      1.136         27        640: 100% ━━━━━━━━━━━━ 75/75 3.4it/s 22.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.9it/s 7.7s
#                    all        702       1266      0.825      0.642      0.709      0.358
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      2.29G     0.9713     0.7542      1.138         31        640: 100% ━━━━━━━━━━━━ 75/75 3.1it/s 23.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 3.2it/s 6.9s
#                    all        702       1266      0.801      0.645      0.706      0.361
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      2.29G      0.958     0.7312      1.129         37        640: 100% ━━━━━━━━━━━━ 75/75 3.1it/s 24.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 3.3it/s 6.6s
#                    all        702       1266      0.813      0.638      0.703      0.361
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      2.29G     0.9437     0.7285      1.125         26        640: 100% ━━━━━━━━━━━━ 75/75 3.2it/s 23.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.9it/s 7.5s
#                    all        702       1266      0.804      0.652      0.707      0.364
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      2.29G     0.9449     0.7267      1.135         19        640: 100% ━━━━━━━━━━━━ 75/75 3.3it/s 22.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.6it/s 8.4s
#                    all        702       1266      0.817      0.647      0.703      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      2.29G       0.96     0.7209      1.127         31        640: 100% ━━━━━━━━━━━━ 75/75 3.3it/s 22.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.7it/s 8.1s
#                    all        702       1266      0.814      0.651      0.705      0.359
#
# 100 epochs completed in 0.917 hours.
# Optimizer stripped from /content/runs/detect/train4/weights/last.pt, 6.3MB
# Optimizer stripped from /content/runs/detect/train4/weights/best.pt, 6.3MB
#
# Validating /content/runs/detect/train4/weights/best.pt...
# Ultralytics 8.3.231 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.0it/s 11.0s
#                    all        702       1266      0.803      0.652      0.707      0.364
#             dead pixel        156        217      0.839      0.544      0.625      0.262
#                scratch        171        399      0.848      0.835      0.847      0.427
#           screen crack        336        650      0.723      0.577      0.649      0.403
# Speed: 0.3ms preprocess, 2.6ms inference, 0.0ms loss, 4.0ms postprocess per image
# Results saved to /content/runs/detect/train4
# Training completed. Results are stored in the 'runs' directory.

# %%
# Now running from epoch 151 to 175 (Iteration 3)
# Re-initialize the model with the best weights from the previous run
model_reloaded2 = ultralytics.YOLO('/content/runs/detect/train4/weights/best.pt')
results = model_reloaded2.train(
    data=data_yaml_path,
    epochs=100,
    imgsz=640,
    batch=16,
    lr0=0.001, #changed
    lrf=0.01,
    optimizer='SGD',
    weight_decay=0.0005,
    momentum=0.937,
    hsv_h=0.015,
    hsv_s=0.7,
    hsv_v=0.4,
    degrees=0.0,
    translate=0.1,
    scale=0.5,
    flipud=0.0,
    fliplr=0.5,
    mosaic=0.5, #changed
    mixup=0.0,
    save_period=10
)
print("Training completed. Results are stored in the 'runs' directory.")
# Out:
# Ultralytics 8.3.231 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/content/runs/detect/train4/weights/best.pt, momentum=0.937, mosaic=0.5, multi_scale=False, name=train5, nbs=64, nms=False, opset=None, optimize=False, optimizer=SGD, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/train5, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751897  ultralytics.nn.modules.head.Detect           [3, [64, 128, 256]]
# Model summary: 129 layers, 3,011,433 parameters, 3,011,417 gradients, 8.2 GFLOPs
#
# Transferred 355/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.6±0.3 ms, read: 29.4±16.0 MB/s, size: 71.6 KB)
# train: Scanning /content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/train/labels.cache... 1199 images, 271 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1199/1199 1.4Mit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 2.2±1.6 ms, read: 10.6±6.1 MB/s, size: 106.3 KB)
# val: Scanning /content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/valid/labels.cache... 702 images, 172 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 702/702 827.3Kit/s 0.0s
# Plotting labels to /content/runs/detect/train5/labels.jpg...
# optimizer: SGD(lr=0.001, momentum=0.937) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/train5
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      2.17G      1.003     0.8307      1.153         41        640: 100% ━━━━━━━━━━━━ 75/75 2.0it/s 37.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.2it/s 10.0s
#                    all        702       1266      0.808      0.642      0.703      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      2.35G      1.007     0.8392      1.156         51        640: 100% ━━━━━━━━━━━━ 75/75 2.2it/s 34.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.4it/s 9.1s
#                    all        702       1266      0.808      0.655      0.714      0.363
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      2.36G     0.9908     0.8252      1.142         44        640: 100% ━━━━━━━━━━━━ 75/75 2.8it/s 27.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.9it/s 7.5s
#                    all        702       1266      0.799       0.65      0.704       0.36
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      2
0.357
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      2.37G     0.8899     0.7165      1.085         38        640: 100% ━━━━━━━━━━━━ 75/75 3.2it/s 23.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.7it/s 8.3s
#                    all        702       1266      0.801      0.653      0.709      0.359
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      2.37G     0.9184     0.7306      1.088         22        640: 100% ━━━━━━━━━━━━ 75/75 2.9it/s 25.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 3.3it/s 6.7s
#                    all        702       1266      0.824      0.643       0.71      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      2.37G     0.8935     0.7119      1.086         27        640: 100% ━━━━━━━━━━━━ 75/75 3.0it/s 25.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 3.1it/s 7.2s
#                    all        702       1266       0.82      0.655      0.714       0.36
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      2.37G     0.8782     0.7004       1.08         27        640: 100% ━━━━━━━━━━━━ 75/75 3.0it/s 25.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.6it/s 8.3s
#                    all        702       1266      0.834      0.646      0.712      0.361
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      2.37G     0.8769     0.6975      1.075         38        640: 100% ━━━━━━━━━━━━ 75/75 3.2it/s 23.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.5it/s 8.8s
#                    all        702       1266      0.848      0.646      0.716      0.361
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      2.37G     0.8836     0.7278      1.181         42        640: 1% ──────────── 1/75 2.6it/s 0.4s<28.7s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-669023893.py in <cell line: 0>()
#       2 # Re-initialize the model with the best weights from the previous run
#       3 model_reloaded2 = ultralytics.YOLO('/content/runs/detect/train4/weights/best.pt')
# ----> 4 results = model_reloaded2.train( # Call train on the reloaded model
#       5     data=data_yaml_path,
#       6     epochs=100,
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in train(self, trainer, **kwargs)
#     771             self.model = self.trainer.model
#     772
# --> 773         self.trainer.train()
#     774         # Update model and cfg after training
#     775         if RANK in {-1, 0}:
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/trainer.py in train(self)
#     241
#     242         else:
# --> 243             self._do_train()
#     244
#     245     def _setup_scheduler(self):
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/trainer.py in _do_train(self)
#     425                         loss, self.loss_items = unwrap_model(self.model).loss(batch, preds)
#     426                     else:
# --> 427                         loss, self.loss_items = self.model(batch)
#     428                     self.loss = loss.sum()
#     429                     if RANK != -1:
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1773             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774         else:
# -> 1775             return self._call_impl(*args, **kwargs)
#    1776
#    1777     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1784                 or _global_backward_pre_hooks or _global_backward_hooks
#    1785                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786             return forward_call(*args, **kwargs)
#    1787
#    1788         result = None
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py in forward(self, x, *args, **kwargs)
#     134         """
#     135         if isinstance(x, dict):  # for cases of training and validating while training.
# --> 136             return self.loss(x, *args, **kwargs)
#     137         return self.predict(x, *args, **kwargs)
#     138
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py in loss(self, batch, preds)
#     326         if preds is None:
#     327             preds = self.forward(batch["img"])
# --> 328         return self.criterion(preds, batch)
#     329
#     330     def init_criterion(self):
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/utils/loss.py in __call__(self, preds, batch)
#     259         # Targets
#     260         targets = torch.cat((batch["batch_idx"].view(-1, 1), batch["cls"].view(-1, 1), batch["bboxes"]), 1)
# --> 261         targets = self.preprocess(targets, batch_size, scale_tensor=imgsz[[1, 0, 1, 0]])
#     262         gt_labels, gt_bboxes = targets.split((1, 4), 2)  # cls, xyxy
#     263         mask_gt = gt_bboxes.sum(2, keepdim=True).gt_(0.0)
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/utils/loss.py in preprocess(self, targets, batch_size, scale_tensor)
#     228                 matches = i == j
#     229                 if n := matches.sum():
# --> 230                     out[j, :n] = targets[matches, 1:]
#     231             out[..., 1:5] = xywh2xyxy(out[..., 1:5].mul_(scale_tensor))
#     232         return out
#
# KeyboardInterrupt:

# %% [markdown]
# ### Model Performance (Saved Models)

# %%
# Evaluate the model on the validation set - Best among first 50 epochs
metrics = model.val(data=data_yaml_path)

print("Model evaluation completed.")
print(f"mAP50-95: {metrics.box.map}")
print(f"mAP50: {metrics.box.map50}")
print(f"mAP75: {metrics.box.map75}")
# Out:
# Ultralytics 8.3.231 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.7±0.2 ms, read: 23.2±15.6 MB/s, size: 37.0 KB)
# val: Scanning /content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/valid/labels.cache... 702 images, 172 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 702/702 948.0Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 44/44 4.7it/s 9.3s
#                    all        702       1266      0.706      0.574       0.63      0.313
#             dead pixel        156        217      0.627      0.442      0.511      0.205
#                scratch        171        399      0.818      0.801      0.829      0.411
#           screen crack        336        650      0.672      0.478      0.548      0.324
# Speed: 1.6ms preprocess, 3.8ms inference, 0.0ms loss, 1.8ms postprocess per image
# Results saved to /content/runs/detect/val2
# Model evaluation completed.
# mAP50-95: 0.31311344558724546
# mAP50: 0.629568846381392
# mAP75: 0.2788643623068785

# %%
# Evaluate the model on the validation set - Best among first 150 epochs
metrics = model_reloaded.val(data=data_yaml_path)

print("Model evaluation completed.")
print(f"mAP50-95: {metrics.box.map}")
print(f"mAP50: {metrics.box.map50}")
print(f"mAP75: {metrics.box.map75}")
# Out:
# Ultralytics 8.3.231 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.3±0.1 ms, read: 17.3±8.8 MB/s, size: 46.1 KB)
# val: Scanning /content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/valid/labels.cache... 702 images, 172 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 702/702 224.9Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 44/44 4.2it/s 10.4s
#                    all        702       1266      0.802      0.651      0.707      0.364
#             dead pixel        156        217      0.836      0.544      0.625      0.261
#                scratch        171        399      0.847      0.832      0.847      0.427
#           screen crack        336        650      0.724      0.577      0.648      0.403
# Speed: 2.1ms preprocess, 3.9ms inference, 0.0ms loss, 1.9ms postprocess per image
# Results saved to /content/runs/detect/val4
# Model evaluation completed.
# mAP50-95: 0.36360411396903825
# mAP50: 0.7067325157262944
# mAP75: 0.3276859072489548

# %%
# Evaluate the model on the validation set - Best among first 225 epochs
metrics = model_reloaded2.val(data=data_yaml_path)

print("Model evaluation completed.")
print(f"mAP50-95: {metrics.box.map}")
print(f"mAP50: {metrics.box.map50}")
print(f"mAP75: {metrics.box.map75}")
# Out:
# Ultralytics 8.3.231 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,006,233 parameters, 13,065 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.5±0.2 ms, read: 47.8±20.4 MB/s, size: 102.2 KB)
# val: Scanning /content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/valid/labels.cache... 702 images, 172 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 702/702 851.2Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 44/44 3.5it/s 12.4s
#                    all        702       1266      0.845      0.645      0.715      0.363
#             dead pixel        156        217      0.897      0.553      0.661      0.269
#                scratch        171        399      0.869      0.815       0.85      0.418
#           screen crack        336        650       0.77      0.566      0.634      0.402
# Speed: 1.4ms preprocess, 3.9ms inference, 0.0ms loss, 2.3ms postprocess per image
# Results saved to /content/runs/detect/val5
# Model evaluation completed.
# mAP50-95: 0.3627970699250239
# mAP50: 0.7151298611048623
# mAP75: 0.3118062277922664

# %%
import shutil
import os

source_path = '/content/runs/detect/train2'
destination_path = '/content/drive/My Drive/DBAI/train2'

# Ensure the destination directory exists
os.makedirs(os.path.dirname(destination_path), exist_ok=True)

# Check if the source path exists before copying
if os.path.exists(source_path):
    # Remove existing destination if it's a directory to prevent errors
    if os.path.exists(destination_path) and os.path.isdir(destination_path):
        shutil.rmtree(destination_path)
    shutil.copytree(source_path, destination_path)
    print(f"Successfully copied '{source_path}' to '{destination_path}'")
else:
    print(f"Error: Source path '{source_path}' does not exist.")
# Out:
# Successfully copied '/content/runs/detect/train2' to '/content/drive/My Drive/DBAI/train2'

# %%
import shutil
import os

source_path = '/content/runs/detect/train4'
destination_path = '/content/drive/My Drive/DBAI/train4'

# Ensure the destination directory exists
os.makedirs(os.path.dirname(destination_path), exist_ok=True)

# Check if the source path exists before copying
if os.path.exists(source_path):
    # Remove existing destination if it's a directory to prevent errors
    if os.path.exists(destination_path) and os.path.isdir(destination_path):
        shutil.rmtree(destination_path)
    shutil.copytree(source_path, destination_path)
    print(f"Successfully copied '{source_path}' to '{destination_path}'")
else:
    print(f"Error: Source path '{source_path}' does not exist.")
# Out:
# Successfully copied '/content/runs/detect/train4' to '/content/drive/My Drive/DBAI/train4'

# %%
import shutil
import os

source_path = '/content/runs/detect/train5'
destination_path = '/content/drive/My Drive/DBAI/train5'

# Ensure the destination directory exists
os.makedirs(os.path.dirname(destination_path), exist_ok=True)

# Check if the source path exists before copying
if os.path.exists(source_path):
    # Remove existing destination if it's a directory to prevent errors
    if os.path.exists(destination_path) and os.path.isdir(destination_path):
        shutil.rmtree(destination_path)
    shutil.copytree(source_path, destination_path)
    print(f"Successfully copied '{source_path}' to '{destination_path}'")
else:
    print(f"Error: Source path '{source_path}' does not exist.")
# Out:
# Successfully copied '/content/runs/detect/train5' to '/content/drive/My Drive/DBAI/train5'

# %% [markdown]
# ## OPTION2 - Using yolov8s model
#
# Train YOLOv8 model using the standard hyperparameters, then evaluate the model on the validation dataset, and finally summarize the training results, including performance metrics and confirmation of saved checkpoints.
# The training data YAML file is located at [/content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/data.yaml](https://)

# %% [markdown]
# ### Setup & Installation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_yaml_path = '/content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/data.yaml' # @param {type: "string"}
print(f"Data YAML path set to: {data_yaml_path}")
# Out:
# Data YAML path set to: /content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/data.yaml

# %%
# !pip install ultralytics
import ultralytics
print("Ultralytics library installed and imported successfully.")
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.232-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.9.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.24.0+cu126)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.31.0)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2025.11.12)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.3.232-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 67.9 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.232 ultralytics-thop-2.0.18
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics library installed and imported successfully.

# %% [markdown]
# ### Load Dataset

# %%
model = ultralytics.YOLO('yolov8s.pt') # Load a pre-trained YOLOv8n model
print("YOLOv8 model initialized:")
print(model.info())
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8s.pt to 'yolov8s.pt': 100% ━━━━━━━━━━━━ 21.5MB 209.3MB/s 0.1s
# YOLOv8 model initialized:
# YOLOv8s summary: 129 layers, 11,166,560 parameters, 0 gradients, 28.8 GFLOPs
# (129, 11166560, 0, 28.816844800000002)

# %% [markdown]
# ### Model Training

# %%
# first 50 epochs (Iteration 1)
results = model.train(
    model='yolov8s.pt',
    data=data_yaml_path,
    epochs=50,
    imgsz=640,
    batch=16,
    lr0=0.01,
    lrf=0.01,
    optimizer='SGD',
    weight_decay=0.0005,
    momentum=0.937,
    hsv_h=0.015,
    hsv_s=0.7,
    hsv_v=0.4,
    degrees=0.0,
    translate=0.1,
    scale=0.5,
    flipud=0.0,
    fliplr=0.5,
    mosaic=1.0,
    mixup=0.0,
    save_period=10
)
print("Training completed. Results are stored in the 'runs' directory.")
# Out:
# Ultralytics 8.3.232 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8s.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=SGD, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/train, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 113.4MB/s 0.0s
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2117209  ultralytics.nn.modules.head.Detect           [3, [128, 256, 512]]
# Model summary: 129 layers, 11,136,761 parameters, 11,136,745 gradients, 28.7 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 188.0MB/s 0.0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.7±0.4 ms, read: 0.1±0.1 MB/s, size: 69.9 KB)
# train: Scanning /content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/train/labels... 1199 images, 271 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1199/1199 2.0it/s 10:05
# train: New cache created: /content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.9±1.0 ms, read: 0.2±0.1 MB/s, size: 113.2 KB)
# val: Scanning /content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/valid/labels... 702 images, 172 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 702/702 2.0it/s 5:46
# val: New cache created: /content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/valid/labels.cache
# Plotting labels to /content/runs/detect/train/labels.jpg...
# optimizer: SGD(lr=0.01, momentum=0.937) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      3.48G      1.897      3.245      1.906         57        640: 100% ━━━━━━━━━━━━ 75/75 2.7it/s 28.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.2it/s 10.2s
#                    all        702       1266       0.71      0.286      0.258      0.111
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      4.26G      1.721      2.371      1.765         35        640: 100% ━━━━━━━━━━━━ 75/75 2.9it/s 25.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.7it/s 8.1s
#                    all        702       1266      0.452      0.323      0.332      0.154
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      4.29G      1.768      2.306      1.719         56        640: 100% ━━━━━━━━━━━━ 75/75 3.0it/s 25.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.5it/s 8.9s
#                    all        702       1266      0.377      0.258      0.248      0.101
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      4.31G      1.816      2.309      1.747         41        640: 100% ━━━━━━━━━━━━ 75/75 3.0it/s 25.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.8it/s 8.0s
#                    all        702       1266       0.39      0.318      0.264     0.0929
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      4.34G      1.824      2.207      1.811         59        640: 100% ━━━━━━━━━━━━ 75/75 3.0it/s 25.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.5it/s 8.6s
#                    all        702       1266      0.464      0.289      0.323      0.135
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      4.36G      1.835      2.207      1.794         52        640: 100% ━━━━━━━━━━━━ 75/75 3.0it/s 25.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.8it/s 8.0s
#                    all        702       1266      0.408      0.378      0.334      0.133
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      4
640: 100% ━━━━━━━━━━━━ 75/75 3.1it/s 24.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.7it/s 8.0s
#                    all        702       1266      0.724      0.613      0.663      0.334
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      5.66G      1.132     0.8791      1.292         29        640: 100% ━━━━━━━━━━━━ 75/75 3.1it/s 24.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.5it/s 8.8s
#                    all        702       1266       0.76      0.653      0.688      0.354
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      5.69G       1.09     0.8373      1.263         28        640: 100% ━━━━━━━━━━━━ 75/75 3.2it/s 23.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.4it/s 9.1s
#                    all        702       1266      0.734      0.649      0.692      0.352
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      5.71G      1.098     0.8536      1.281         18        640: 100% ━━━━━━━━━━━━ 75/75 3.0it/s 24.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.9it/s 7.6s
#                    all        702       1266      0.763      0.668      0.706      0.355
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      5.73G      1.077     0.8195      1.257         28        640: 100% ━━━━━━━━━━━━ 75/75 3.1it/s 24.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.4it/s 9.2s
#                    all        702       1266      0.747      0.659      0.692      0.354
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      5.76G       1.06      0.817      1.232         32        640: 100% ━━━━━━━━━━━━ 75/75 3.2it/s 23.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.5it/s 8.7s
#                    all        702       1266      0.759      0.665      0.704      0.351
#
# 50 epochs completed in 0.477 hours.
# Optimizer stripped from /content/runs/detect/train/weights/last.pt, 22.5MB
# Optimizer stripped from /content/runs/detect/train/weights/best.pt, 22.5MB
#
# Validating /content/runs/detect/train/weights/best.pt...
# Ultralytics 8.3.232 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,126,745 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.1it/s 10.4s
#                    all        702       1266      0.764      0.667      0.706      0.354
#             dead pixel        156        217      0.729      0.599      0.614      0.258
#                scratch        171        399      0.851       0.83      0.865      0.417
#           screen crack        336        650      0.712      0.574      0.639      0.388
# Speed: 0.3ms preprocess, 4.7ms inference, 0.0ms loss, 3.4ms postprocess per image
# Results saved to /content/runs/detect/train
# Training completed. Results are stored in the 'runs' directory.

# %%
# Now running from epoch 51 to 150 (Iteration 2)
# Re-initialize the model with the best weights from the previous run
model_reloaded = ultralytics.YOLO('/content/runs/detect/train/weights/best.pt')
results = model_reloaded.train(
    data=data_yaml_path,
    epochs=100,
    imgsz=640,
    batch=16,
    lr0=0.01,
    lrf=0.01,
    optimizer='SGD',
    weight_decay=0.0005,
    momentum=0.937,
    hsv_h=0.015,
    hsv_s=0.7,
    hsv_v=0.4,
    degrees=0.0,
    translate=0.1,
    scale=0.5,
    flipud=0.0,
    fliplr=0.5,
    mosaic=1.0,
    mixup=0.0,
    save_period=15
)
print("Training completed. Results are stored in the 'runs' directory.")
# Out:
# Ultralytics 8.3.232 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/content/runs/detect/train/weights/best.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train2, nbs=64, nms=False, opset=None, optimize=False, optimizer=SGD, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/train2, save_frames=False, save_json=False, save_period=15, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2117209  ultralytics.nn.modules.head.Detect           [3, [128, 256, 512]]
# Model summary: 129 layers, 11,136,761 parameters, 11,136,745 gradients, 28.7 GFLOPs
#
# Transferred 355/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.7±0.3 ms, read: 44.7±29.4 MB/s, size: 71.6 KB)
# train: Scanning /content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/train/labels.cache... 1199 images, 271 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1199/1199 844.6Kit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.5±0.1 ms, read: 59.7±23.4 MB/s, size: 106.3 KB)
# val: Scanning /content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/valid/labels.cache... 702 images, 172 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 702/702 724.0Kit/s 0.0s
# Plotting labels to /content/runs/detect/train2/labels.jpg...
# optimizer: SGD(lr=0.01, momentum=0.937) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/train2
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      3.71G      1.164      1.053      1.298         57        640: 100% ━━━━━━━━━━━━ 75/75 2.2it/s 33.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.6it/s 8.6s
#                    all        702       1266      0.775      0.635      0.694       0.35
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      4.03G      1.191      1.025      1.308         35        640: 100% ━━━━━━━━━━━━ 75/75 2.8it/s 26.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.5it/s 8.8s
#                    all        702       1266      0.694      0.614      0.643      0.308
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      4.03G      1.262      1.157      1.355         56        640: 100% ━━━━━━━━━━━━ 75/75 2.9it/s 25.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.5it/s 9.0s
#                    all        702       1266      0.635      0.572      0.599      0.278
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      4.03G      1.342      1.305      1.399         41        640: 100% ━━━━━━━━━━━━ 75/75 2.9it/s 26.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.6it/s 8.5s
#                    all        702       1266      0.557      0.502      0.525      0.233
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      4.03G      1.384      1.375      1.435         59        640: 100% ━━━━━━━━━━━━ 75/75 3.0it/s 25.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.3it/s 9.4s
#                    all        702       1266       0.61      0.532      0.566      0.253
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      4.03G       1.44      1.449       1.44         52        640: 100% ━━━━━━━━━━━━ 75/75 2.9it/s 25.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.9it/s 7.6s
#                    all        702       1266      0.519      0.502      0.493      0.223
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      4.03G      1.439      1.485       1.47         32        640: 100% ━━━━━━━━━━━━ 75/75 2.9it/s 26.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.5it/s 8.8s
#                    all        702       1266       0.61      0.514      0.537      0.252
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      4.03G      1.435      1.456      1.473         39        640: 100% ━━━━━━━━━━━━ 75/75 3.1it/s 24.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.4it/s 9.1s
#                    all        702       1266      0.579      0.545      0.545      0.257
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      4.03G      1.441      1.462      1.474         41        640: 100% ━━━━━━━━━━━━ 75/75 2.9it/s 25.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.7it/s 8.1s
#                    all        702       1266      0.556      0.557      0.539      0.248
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      4.03G      1.395      1.413      1.452         34        640: 100% ━━━━━━━━━━━━ 75/75 3.0it/s 24.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.3it/s 9.5s
#                    all        702       1266      0.568      0.524      0.538      0.237
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      4.03G      1.415      1.412      1.456         74        640: 100% ━━━━━━━━━━━━ 75/75 2.9it/s 26.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.8it/s 7.9s
#                    all        702       1266        0.6      0.544       0.55       0.25
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      4.03G      1.428      1.404      1.462         51        640: 100% ━━━━━━━━━━━━ 75/75 2.9it/s 26.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.4it/s 9.0s
#                    all        702       1266      0.561      0.564      0.563      0.262
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      4.03G      1.396      1.359      1.434         28        640: 100% ━━━━━━━━━━━━ 75/75 2.9it/s 26.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.8it/s 7.9s
#                    all        702       1266      0.663      0.536      0.585      0.276
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      4.03G      1.367      1.361       1.43         49        640: 100% ━━━━━━━━━━━━ 75/75 2.8it/s 26.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.6it/s 8.4s
#                    all        702       1266      0.648      0.551      0.572      0.269
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      4.03G      1.359      1.321      1.406         45        640: 100% ━━━━━━━━━━━━ 75/75 3.0it/s 25.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.4it/s 9.2s
#                    all        702       1266      0.557      0.505      0.528      0.253
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      4.03G       1.37      1.331      1.415         38        640: 100% ━━━━━━━━━━━━ 75/75 2.8it/s 26.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.6it/s 8.4s
#                    all        702       1266      0.504      0.496      0.463      0.203
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      4.03G      1.354      1.322      1.401         41        640: 100% ━━━━━━━━━━━━ 75/75 2.9it/s 26.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.4it/s 9
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100       4.1G     0.8042     0.5485      1.051         26        640: 100% ━━━━━━━━━━━━ 75/75 2.8it/s 27.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.4it/s 9.2s
#                    all        702       1266      0.824      0.639      0.704       0.36
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100       4.1G     0.7703     0.5104       1.03         35        640: 100% ━━━━━━━━━━━━ 75/75 3.0it/s 24.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.9it/s 7.7s
#                    all        702       1266      0.812      0.654      0.703      0.366
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100       4.1G     0.7523     0.4895      1.016         26        640: 100% ━━━━━━━━━━━━ 75/75 3.0it/s 24.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.5it/s 8.9s
#                    all        702       1266      0.817       0.66      0.714      0.368
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100       4.1G     0.7537     0.4768      1.011         40        640: 100% ━━━━━━━━━━━━ 75/75 3.2it/s 23.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.4it/s 9.1s
#                    all        702       1266      0.825      0.653      0.709      0.368
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100       4.1G     0.7298     0.4581      1.008         27        640: 100% ━━━━━━━━━━━━ 75/75 3.0it/s 24.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.8it/s 7.7s
#                    all        702       1266      0.799      0.659      0.711      0.374
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100       4.1G     0.7439     0.4703      1.005         31        640: 100% ━━━━━━━━━━━━ 75/75 3.0it/s 24.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.5it/s 8.9s
#                    all        702       1266      0.804      0.644      0.709      0.376
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100       4.1G     0.7211     0.4676     0.9983         37        640: 100% ━━━━━━━━━━━━ 75/75 3.1it/s 24.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.6it/s 8.4s
#                    all        702       1266      0.818      0.648      0.714      0.384
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100       4.1G     0.7208     0.4702     0.9992         26        640: 100% ━━━━━━━━━━━━ 75/75 3.1it/s 24.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.9it/s 7.6s
#                    all        702       1266       0.83      0.658      0.715      0.384
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100       4.1G     0.7153     0.4669      1.003         19        640: 100% ━━━━━━━━━━━━ 75/75 3.0it/s 24.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.4it/s 9.0s
#                    all        702       1266      0.819      0.668      0.716      0.382
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100       4.1G     0.6989     0.4512      0.988         31        640: 100% ━━━━━━━━━━━━ 75/75 3.1it/s 24.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.5it/s 8.7s
#                    all        702       1266      0.809      0.661      0.717      0.382
#
# 100 epochs completed in 0.964 hours.
# Optimizer stripped from /content/runs/detect/train2/weights/last.pt, 22.5MB
# Optimizer stripped from /content/runs/detect/train2/weights/best.pt, 22.5MB
#
# Validating /content/runs/detect/train2/weights/best.pt...
# Ultralytics 8.3.232 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,126,745 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.2it/s 10.1s
#                    all        702       1266      0.839      0.652      0.715      0.384
#             dead pixel        156        217      0.827      0.552      0.619      0.281
#                scratch        171        399      0.853       0.82      0.847      0.426
#           screen crack        336        650      0.836      0.585       0.68      0.446
# Speed: 0.2ms preprocess, 4.6ms inference, 0.0ms loss, 3.7ms postprocess per image
# Results saved to /content/runs/detect/train2
# Training completed. Results are stored in the 'runs' directory.

# %% [markdown]
# ### Model Performance (Saved Model)

# %%
# Evaluate the model on the validation set - Best among first 50 epochs
metrics = model.val(data=data_yaml_path)

print("Model evaluation completed.")
print(f"mAP50-95: {metrics.box.map}")
print(f"mAP50: {metrics.box.map50}")
print(f"mAP75: {metrics.box.map75}")
# Out:
# Ultralytics 8.3.232 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,126,745 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access ✅ (ping: 0.5±0.2 ms, read: 45.1±13.0 MB/s, size: 88.8 KB)
# val: Scanning /content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/valid/labels.cache... 702 images, 172 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 702/702 1.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 44/44 2.9it/s 15.4s
#                    all        702       1266      0.763      0.664      0.703      0.353
#             dead pixel        156        217      0.723       0.59      0.607      0.257
#                scratch        171        399      0.852       0.83      0.865      0.415
#           screen crack        336        650      0.713      0.572      0.639      0.388
# Speed: 1.9ms preprocess, 9.6ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to /content/runs/detect/val
# Model evaluation completed.
# mAP50-95: 0.3534920292896381
# mAP50: 0.7034935931963391
# mAP75: 0.30599540552342147

# %%
# Evaluate the model on the validation set - Best among first 150 epochs
metrics = model_reloaded.val(data=data_yaml_path)

print("Model evaluation completed.")
print(f"mAP50-95: {metrics.box.map}")
print(f"mAP50: {metrics.box.map50}")
print(f"mAP75: {metrics.box.map75}")
# Out:
# Ultralytics 8.3.232 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,126,745 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access ✅ (ping: 0.4±0.2 ms, read: 45.7±19.7 MB/s, size: 102.2 KB)
# val: Scanning /content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/valid/labels.cache... 702 images, 172 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 702/702 1.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 44/44 2.8it/s 15.9s
#                    all        702       1266      0.826      0.655      0.713      0.384
#             dead pixel        156        217      0.812      0.562      0.613      0.278
#                scratch        171        399      0.844       0.82      0.846      0.427
#           screen crack        336        650      0.822      0.585       0.68      0.446
# Speed: 2.0ms preprocess, 9.6ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to /content/runs/detect/val2
# Model evaluation completed.
# mAP50-95: 0.38383155233706717
# mAP50: 0.7130754420680144
# mAP75: 0.3654113532944719

# %%
import shutil
import os

source_path = '/content/runs/detect/train2'
destination_path = '/content/drive/My Drive/DBAI/train2'

# Ensure the destination directory exists
os.makedirs(os.path.dirname(destination_path), exist_ok=True)

# Check if the source path exists before copying
if os.path.exists(source_path):
    # Remove existing destination if it's a directory to prevent errors
    if os.path.exists(destination_path) and os.path.isdir(destination_path):
        shutil.rmtree(destination_path)
    shutil.copytree(source_path, destination_path)
    print(f"Successfully copied '{source_path}' to '{destination_path}'")
else:
    print(f"Error: Source path '{source_path}' does not exist.")
# Out:
# Successfully copied '/content/runs/detect/train2' to '/content/drive/My Drive/DBAI/train2'

# %% [markdown]
# ## OPTION3 - Using yolov8m model
#
# Train YOLOv8 model using the standard hyperparameters, then evaluate the model on the validation dataset, and finally summarize the training results, including performance metrics and confirmation of saved checkpoints.
# The training data YAML file is located at [/content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/data.yaml](https://)

# %% [markdown]
# ### Setup & Installation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_yaml_path = '/content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/data.yaml' # @param {type: "string"}
print(f"Data YAML path set to: {data_yaml_path}")
# Out:
# Data YAML path set to: /content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/data.yaml

# %%
# !pip install ultralytics
import ultralytics
print("Ultralytics library installed and imported successfully.")
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.232-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.9.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.24.0+cu126)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.31.0)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2025.11.12)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.3.232-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 27.3 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.232 ultralytics-thop-2.0.18
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics library installed and imported successfully.

# %% [markdown]
# ### Load Dataset

# %%
model = ultralytics.YOLO('yolov8m.pt') # Load a pre-trained YOLOv8n model
print("YOLOv8 model initialized:")
print(model.info())
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8m.pt to 'yolov8m.pt': 100% ━━━━━━━━━━━━ 49.7MB 284.8MB/s 0.2s
# YOLOv8 model initialized:
# YOLOv8m summary: 169 layers, 25,902,640 parameters, 0 gradients, 79.3 GFLOPs
# (169, 25902640, 0, 79.3204224)

# %% [markdown]
# ### Model Training & Performance

# %%
# first 60 epochs (Iteration 1)
results = model.train(
    model='yolov8m.pt',
    data=data_yaml_path,
    epochs=100,
    imgsz=640,
    batch=16,
    lr0=0.01,
    lrf=0.01,
    optimizer='SGD',
    weight_decay=0.0005,
    momentum=0.937,
    hsv_h=0.015,
    hsv_s=0.7,
    hsv_v=0.4,
    degrees=0.0,
    translate=0.1,
    scale=0.5,
    flipud=0.0,
    fliplr=0.5,
    mosaic=1.0,
    mixup=0.0,
    save_period=10
)
print("Training completed. Results are stored in the 'runs' directory.")
# Out:
# Ultralytics 8.3.232 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8m.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=SGD, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/train, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 27.5MB/s 0.0s
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3777433  ultralytics.nn.modules.head.Detect           [3, [192, 384, 576]]
# Model summary: 169 layers, 25,858,057 parameters, 25,858,041 gradients, 79.1 GFLOPs
#
# Transferred 469/475 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 56.2MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 1.2±1.3 ms, read: 0.1±0.1 MB/s, size: 69.9 KB)
# train: Scanning /content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/train/labels.cache... 1199 images, 271 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1199/1199 1.6Mit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 1.5±2.1 ms, read: 0.3±0.1 MB/s, size: 113.2 KB)
# val: Scanning /content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/valid/labels.cache... 702 images, 172 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 702/702 787.9Kit/s 0.0s
# Plotting labels to /content/runs/detect/train/labels.jpg...
# optimizer: SGD(lr=0.01, momentum=0.937) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.0005), 83 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      6.31G      1.871      3.425      1.899         57        640: 100% ━━━━━━━━━━━━ 75/75 1.3it/s 56.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 14.7s/it 5:24
#                    all        702       1266      0.755      0.289        0.3      0.137
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100       6.5G      1.702      2.317      1.722         35        640: 100% ━━━━━━━━━━━━ 75/75 1.8it/s 41.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.2it/s 10
0.272
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100       6.5G      1.392      1.385      1.474         43        640: 100% ━━━━━━━━━━━━ 75/75 1.9it/s 39.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.3it/s 9.5s
#                    all        702       1266      0.681      0.562      0.607      0.285
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      6.51G      1.363      1.353      1.456         64        640: 100% ━━━━━━━━━━━━ 75/75 1.9it/s 40.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.3it/s 9.7s
#                    all        702       1266      0.663       0.55      0.588      0.288
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      6.52G      1.351      1.338      1.446         48        640: 100% ━━━━━━━━━━━━ 75/75 1.9it/s 40.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.2it/s 10.0s
#                    all        702       1266      0.661      0.528       0.57      0.275
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      6.43G      1.346      1.292      1.433         41        640: 100% ━━━━━━━━━━━━ 75/75 1.9it/s 40.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.3it/s 9.4s
#                    all        702       1266       0.64      0.555       0.59      0.274
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100       6.5G      1.294      1.263      1.402         44        640: 100% ━━━━━━━━━━━━ 75/75 1.9it/s 39.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.2it/s 9.9s
#                    all        702       1266      0.721      0.581      0.624      0.306
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      6.48G      1.333      1.267      1.421         48        640: 100% ━━━━━━━━━━━━ 75/75 1.9it/s 40.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.2it/s 9.9s
#                    all        702       1266      0.726       0.56      0.614      0.301
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100       6.5G      1.311      1.267      1.407         24        640: 100% ━━━━━━━━━━━━ 75/75 1.9it/s 40.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.4it/s 9.2s
#                    all        702       1266      0.673      0.576      0.611      0.296
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      6.43G      1.298      1.251      1.402         61        640: 100% ━━━━━━━━━━━━ 75/75 1.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.3it/s 9.7s
#                    all        702       1266      0.719      0.573      0.636      0.306
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      6.47G      1.301      1.238      1.405         53        640: 100% ━━━━━━━━━━━━ 75/75 1.9it/s 40.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.2it/s 9.9s
#                    all        702       1266      0.735      0.583      0.638      0.309
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      6.49G      1.289      1.192        1.4         42        640: 100% ━━━━━━━━━━━━ 75/75 1.9it/s 40.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.4it/s 9.1s
#                    all        702       1266      0.739      0.602      0.653      0.315
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      6.52G      1.278      1.174      1.402         73        640: 100% ━━━━━━━━━━━━ 75/75 1.9it/s 40.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.4it/s 9.1s
#                    all        702       1266      0.717      0.594      0.632      0.312
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      6.41G      1.223      1.148      1.358         55        640: 100% ━━━━━━━━━━━━ 75/75 1.9it/s 39.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.2it/s 10.1s
#                    all        702       1266      0.771      0.602      0.663      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      6.49G      1.236      1.131      1.358         34        640: 100% ━━━━━━━━━━━━ 75/75 1.9it/s 40.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.2it/s 10.0s
#                    all        702       1266      0.693      0.601      0.664      0.318
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100       6.5G      1.197      1.107      1.334         44        640: 100% ━━━━━━━━━━━━ 75/75 1.9it/s 40.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.4it/s 9.2s
#                    all        702       1266      0.741      0.607      0.667      0.328
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      6.51G        1.2      1.077      1.342         35        640: 100% ━━━━━━━━━━━━ 75/75 1.9it/s 40.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.2it/s 10.0s
#                    all        702       1266      0.791      0.624      0.688      0.342
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      6.43G      1.199      1.087      1.339         47        640: 100% ━━━━━━━━━━━━ 75/75 1.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.2it/s 9.8s
#                    all        702       1266      0.769      0.616      0.683      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100       6.5G      1.179      1.052       1.32         50        640: 100% ━━━━━━━━━━━━ 75/75 1.9it/s 40.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.4it/s 9.3s
#                    all        702       1266      0.754      0.603      0.663      0.335
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      6.49G      1.164      1.053      1.314         44        640: 100% ━━━━━━━━━━━━ 75/75 1.9it/s 40.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.2it/s 9.9s
#                    all        702       1266       0.73      0.638      0.686      0.343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      6.52G      1.163      1.038      1.318         49        640: 100% ━━━━━━━━━━━━ 75/75 1.9it/s 40.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.3it/s 9.7s
#                    all        702       1266      0.756      0.632        0.7       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      6.41G      1.155      1.003        1.3         49        640: 100% ━━━━━━━━━━━━ 75/75 1.9it/s 39.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.3it/s 9.4s
#                    all        702       1266      0.771      0.626      0.678      0.337
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100       6.5G      1.155     0.9822      1.297         28        640: 100% ━━━━━━━━━━━━ 75/75 1.9it/s 40.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.2it/s 9.9s
#                    all        702       1266      0.803      0.625      0.687      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      6.49G      1.146      1.006      1.286         49        640: 100% ━━━━━━━━━━━━ 75/75 1.9it/s 40.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.4it/s 9.2s
#                    all        702       1266      0.775      0.634      0.683      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100       6.5G      1.151      0.979      1.284         42        640: 100% ━━━━━━━━━━━━ 75/75 1.9it/s 40.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.3it/s 9.5s
#                    all        702       1266      0.798       0.58      0.669      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      6.39G      1.133     0.9431      1.289         37        640: 100% ━━━━━━━━━━━━ 75/75 1.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.2it/s 9.9s
#                    all        702       1266      0.761      0.627       0.69      0.349
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      6.49G      1.129     0.9454      1.269         33        640: 100% ━━━━━━━━━━━━ 75/75 1.9it/s 40.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.4it/s 9.1s
#                    all        702       1266      0.773      0.625      0.699      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      6.48G      1.107     0.9031      1.269         45        640: 100% ━━━━━━━━━━━━ 75/75 1.9it/s 39.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 2.3it/s 9.8s
#                    all        702       1266      0.749      0.635      0.694      0.355
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      6.51G      1.156      0.899      1.262         73        640: 3% ──────────── 2/75 1.3it/s 1.4s<57.1s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1909431962.py in <cell line: 0>()
#       1 # first 50 epochs
# ----> 2 results = model.train(
#       3     model='yolov8m.pt',
#       4     data=data_yaml_path,
#       5     epochs=100,
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in train(self, trainer, **kwargs)
#     771             self.model = self.trainer.model
#     772
# --> 773         self.trainer.train()
#     774         # Update model and cfg after training
#     775         if RANK in {-1, 0}:
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/trainer.py in train(self)
#     241
#     242         else:
# --> 243             self._do_train()
#     244
#     245     def _setup_scheduler(self):
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/trainer.py in _do_train(self)
#     434                 self.scaler.scale(self.loss).backward()
#     435                 if ni - last_opt_step >= self.accumulate:
# --> 436                     self.optimizer_step()
#     437                     last_opt_step = ni
#     438
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/trainer.py in optimizer_step(self)
#     680         """Perform a single step of the training optimizer with gradient clipping and EMA update."""
#     681         self.scaler.unscale_(self.optimizer)  # unscale gradients
# --> 682         torch.nn.utils.clip_grad_norm_(self.model.parameters(), max_norm=10.0)
#     683         self.scaler.step(self.optimizer)
#     684         self.scaler.update()
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/utils/clip_grad.py in _no_grad_wrapper(*args, **kwargs)
#      41     def _no_grad_wrapper(*args, **kwargs):
#      42         with torch.no_grad():
# ---> 43             return func(*args, **kwargs)
#      44
#      45     functools.update_wrapper(_no_grad_wrapper, func)
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/utils/clip_grad.py in clip_grad_norm_(parameters, max_norm, norm_type, error_if_nonfinite, foreach)
#     229             )
#     230     grads = [p.grad for p in parameters if p.grad is not None]
# --> 231     total_norm = _get_total_norm(grads, norm_type, error_if_nonfinite, foreach)
#     232     _clip_grads_with_norm_(parameters, max_norm, total_norm, foreach)
#     233     return total_norm
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/utils/clip_grad.py in _no_grad_wrapper(*args, **kwargs)
#      41     def _no_grad_wrapper(*args, **kwargs):
#      42         with torch.no_grad():
# ---> 43             return func(*args, **kwargs)
#      44
#      45     functools.update_wrapper(_no_grad_wrapper, func)
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/utils/clip_grad.py in _get_total_norm(tensors, norm_type, error_if_nonfinite, foreach)
#      94             foreach and _device_has_foreach_support(device)
#      95         ):
# ---> 96             norms.extend(torch._foreach_norm(device_tensors, norm_type))
#      97         elif foreach:
#      98             raise RuntimeError(
#
# KeyboardInterrupt:

# %% [markdown]
# ### Model Performance (Saved Models)

# %%
# Evaluate the model on the validation set - best among first 60 epochs
metrics = model.val(data=data_yaml_path)

print("Model evaluation completed.")
print(f"mAP50-95: {metrics.box.map}")
print(f"mAP50: {metrics.box.map50}")
print(f"mAP75: {metrics.box.map75}")
# Out:
# Ultralytics 8.3.232 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 92 layers, 25,841,497 parameters, 14,217 gradients, 78.7 GFLOPs
# val: Fast image access ✅ (ping: 0.6±0.2 ms, read: 43.4±15.0 MB/s, size: 88.8 KB)
# val: Scanning /content/drive/My Drive/DBAI/Mobile Damage Diagnosis.yolov8/valid/labels.cache... 702 images, 172 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 702/702 1.5Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 44/44 2.0it/s 22.0s
#                    all        702       1266      0.763       0.63      0.696      0.355
#             dead pixel        156        217      0.707      0.553      0.622      0.283
#                scratch        171        399      0.862      0.789      0.845       0.41
#           screen crack        336        650       0.72      0.546      0.622      0.371
# Speed: 1.1ms preprocess, 22.2ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to /content/runs/detect/val
# Model evaluation completed.
# mAP50-95: 0.3547335165205399
# mAP50: 0.6963965869097056
# mAP75: 0.32071654900583857

# %%
import shutil
import os

source_path = '/content/runs/detect/train'
destination_path = '/content/drive/My Drive/DBAI/train'

# Ensure the destination directory exists
os.makedirs(os.path.dirname(destination_path), exist_ok=True)

# Check if the source path exists before copying
if os.path.exists(source_path):
    # Remove existing destination if it's a directory to prevent errors
    if os.path.exists(destination_path) and os.path.isdir(destination_path):
        shutil.rmtree(destination_path)
    shutil.copytree(source_path, destination_path)
    print(f"Successfully copied '{source_path}' to '{destination_path}'")
else:
    print(f"Error: Source path '{source_path}' does not exist.")
# Out:
# Successfully copied '/content/runs/detect/train5' to '/content/drive/My Drive/DBAI/train5'
